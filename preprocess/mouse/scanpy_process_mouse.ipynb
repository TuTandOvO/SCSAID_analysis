# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import anndata as ad
import scvi
import scanpy as sc
import os
seed=10
sc.logging.print_versions()
# Out:
# /gpfsdata/home/renyixiang/miniconda3/envs/scrna/lib/python3.10/site-packages/louvain/__init__.py:54: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound
# google-generativeai	0.8.5
# google-auth	2.40.3
# torchmetrics	1.8.2
# six	1.17.0
# python-dateutil	2.9.0.post0
# nvidia-cuda-nvrtc-cu12	12.4.127
# numba	0.61.2
# mpmath	1.3.0
# sympy	1.13.1
# psutil	7.0.0
# jaraco.functools	4.0.1
# setuptools	80.9.0
# executing	2.2.0
# pytz	2025.2
# nvidia-nvjitlink-cu12	12.4.127
# google-api-core	2.25.1
# multipledispatch	1.0.0 (0.6.0)
# louvain	0.8.2
# nvidia-nccl-cu12	2.21.5
# nvidia-cublas-cu12	12.4.5.8
# jaraco.text	3.12.1
# nvidia-cuda-runtime-cu12	12.4.127
# cycler	0.12.1
# torch	2.6.0 (2.6.0+cu124)
# nvidia-nvtx-cu12	12.4.127
# ...

# %%
# GSE269455

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE269455"
gsm_ids = ["GSM8316001","GSM8316002","GSM8316003"]

condition_dict = {
    "GSM8316001": "Healthy",
    "GSM8316002": "alopecia areata",
    'GSM8316003': 'alopecia areata and antibody'
}

sex_dict = {
    "GSM8316001": "Not mentioned",
    "GSM8316002": "Not mentioned",
    'GSM8316003': 'Not mentioned'
}

GSE269455 = {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE269455[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE269455/GSM8316001/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE269455/GSM8316002/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE269455/GSM8316003/pre-processed_anndata.h5ad

# %%
# GSE261227

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE261227"
gsm_ids = ["GSM8138118", "GSM8138119", "GSM8138120", "GSM8138121"]

condition_dict = {
    "GSM8138118": "Healthy",
    "GSM8138119": "Healthy",
    "GSM8138120": "Healthy",
    "GSM8138121": "Healthy"
}

sex_dict = {
    "GSM8138118": "female",
    "GSM8138119": "female",
    "GSM8138120": "female",
    "GSM8138121": "female"
}

GSE261227 = {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE261227[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE261227/GSM8138118/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE261227/GSM8138119/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE261227/GSM8138120/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE261227/GSM8138121/pre-processed_anndata.h5ad

# %%
# GSE234269

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE234269"
gsm_ids = ["GSM7461430", "GSM7461431"]

condition_dict = {
    "GSM7461430": "Wounded 3d",
    "GSM7461431": "Wounded 7d"
}

sex_dict = {
    "GSM7461430": "Not mentioned",
    "GSM7461431": "Not mentioned"
}

GSE234269 = {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE234269[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE234269/GSM7461430/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE234269/GSM7461431/pre-processed_anndata.h5ad

# %%
# GSE230512

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE230512"
gsm_ids = ["GSM7225686", "GSM7225687",'GSM7225688','GSM7225689']

condition_dict = {
    "GSM7225686": "Healthy",
    "GSM7225687": "Intradermal S. aureus infection",
    'GSM7225688': 'Healthy',
    'GSM7225689': 'Topical imiquimod'
}

sex_dict = {
    "GSM7225686": "Not mentioned",
    "GSM7225687": "Not mentioned",
    'GSM7225688': 'Not mentioned',
    'GSM7225689': 'Not mentioned'
}

GSE230512 = {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE230512[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE230512/GSM7225686/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE230512/GSM7225687/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE230512/GSM7225688/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE230512/GSM7225689/pre-processed_anndata.h5ad

# %%
# GSE211810

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE211810"
gsm_ids = ["GSM6502671", "GSM6502672",'GSM6502673','GSM6502674']

condition_dict = {
    "GSM6502671": "Healthy",
    "GSM6502672": "Bleomycin process",
    'GSM6502673': 'Bleomycin process',
    'GSM6502674': 'Healthy'
}

sex_dict = {
    "GSM6502671": "Not mentioned",
    "GSM6502672": "Not mentioned",
    'GSM6502673': 'Not mentioned',
    'GSM6502674': 'Not mentioned'
}

GSE211810 = {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE211810[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE211810/GSM6502671/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE211810/GSM6502672/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE211810/GSM6502673/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE211810/GSM6502674/pre-processed_anndata.h5ad

# %%
# GSE211381

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE211381"
gsm_ids = ["GSM6468127", "GSM6468128",'GSM6468129',
           'GSM6468130','GSM6468131','GSM6468132']

condition_dict = {
    "GSM6468127": "Healthy",
    "GSM6468128": "Healthy",
    'GSM6468129': 'Healthy',
    'GSM6468130': 'Healthy',
    'GSM6468131': 'Alk1 KO',
    'GSM6468132': 'Alk1 KO'
}

sex_dict = {
    "GSM6468127": "Not mentioned",
    "GSM6468128": "Not mentioned",
    'GSM6468129': 'Not mentioned',
    'GSM6468130': 'Not mentioned',
    'GSM6468131': 'Not mentioned',
    'GSM6468132': 'Not mentioned'
}

GSE211381 = {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE211381[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE211381/GSM6468127/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE211381/GSM6468128/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE211381/GSM6468129/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE211381/GSM6468130/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE211381/GSM6468131/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE211381/GSM6468132/pre-processed_anndata.h5ad

# %%
# GSE211279

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE211279"
gsm_ids = ["GSM6460378"]

condition_dict = {
    "GSM6460378": "Cancnes infected"
}

sex_dict = {
    "GSM6460378": "Not mentioned"
}

GSE211279 = {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE211279[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE211279/GSM6460378/pre-processed_anndata.h5ad

# %%
# GSE210224

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE210224"
gsm_ids = ["GSM6423811", "GSM6423812", "GSM6423813", 'GSM6423814',
           'GSM6423815', 'GSM6423816', 'GSM6423817',
           'GSM6423818', 'GSM6423819', 'GSM6423820',
           'GSM6423821', 'GSM6423822']

condition_dict = {
    "GSM6423811": "Trichophyton rubrum infection",
    "GSM6423812": "Trichophyton rubrum infection",
    "GSM6423813": "Trichophyton rubrum infection",
    'GSM6423814': 'Healthy',
    'GSM6423815': 'Healthy',
    'GSM6423816': 'Healthy',
    'GSM6423817': 'Trichophyton rubrum infection',
    'GSM6423818': 'Trichophyton rubrum infection',
    'GSM6423819': 'Trichophyton rubrum infection',
    'GSM6423820': 'Healthy',
    'GSM6423821': 'Healthy',
    'GSM6423822': 'Healthy'
    }

sex_dict = {
    "GSM6423811": "Not mentioned",
    "GSM6423812": "Not mentioned",
    "GSM6423813": "Not mentioned",
    'GSM6423814': 'Not mentioned',
    'GSM6423815': 'Not mentioned',
    'GSM6423816': 'Not mentioned',
    'GSM6423817': 'Not mentioned',
    'GSM6423818': 'Not mentioned',
    'GSM6423819': 'Not mentioned',
    'GSM6423820': 'Not mentioned',
    'GSM6423821': 'Not mentioned',
    'GSM6423822': 'Not mentioned'
}

GSE210224 = {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE210224[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE210224/GSM6423811/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE210224/GSM6423812/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE210224/GSM6423813/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE210224/GSM6423814/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE210224/GSM6423815/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE210224/GSM6423816/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE210224/GSM6423817/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE210224/GSM6423818/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE210224/GSM6423819/pre-processed_anndata.h5ad
# ...

# %%
# GSE205020

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE205020"
gsm_ids = ["GSM6204200","GSM6204201"]

condition_dict = {
    "GSM6204200": "Healthy",
    "GSM6204201": "imiquimod (IMQ)-induced"
}

sex_dict = {
    "GSM6204200": "Not mentioned",
    "GSM6204201": "Not mentioned"
}

GSE205020 = {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE205020[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE205020/GSM6204200/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE205020/GSM6204201/pre-processed_anndata.h5ad

# %%
# GSE223660

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE223660"
gsm_ids = ["GSM6970228"]

condition_dict = {
    "GSM6970228": "wounded"
}

sex_dict = {
    "GSM6970228": "Not mentioned"
}

GSE223660 = {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE223660[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE223660/GSM6970228/pre-processed_anndata.h5ad

# %%
# GSE196677

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE196677"
gsm_ids = ["GSM5898068","GSM5898069","GSM5898070"]

condition_dict = {
    "GSM5898068": "Healthy",
    "GSM5898069": "Shi-Bi-Man Smear",
    "GSM5898070": "Shi-Bi-Man Mouth"
}

sex_dict = {
    "GSM5898068": "Not mentioned",
    "GSM5898069": "Not mentioned",
    "GSM5898070": "Not mentioned"
}

GSE196677 = {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE196677[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE196677/GSM5898068/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE196677/GSM5898069/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE196677/GSM5898070/pre-processed_anndata.h5ad

# %%
# GSE189210

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE189210"
gsm_ids = ["GSM5696148"]

condition_dict = {
    "GSM5696148": "Healthy"
}

sex_dict = {
    "GSM5696148": "Not mentioned"
}

GSE189210 = {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE189210[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE189210/GSM5696148/pre-processed_anndata.h5ad

# %%
# GSE158691

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE158691"
gsm_ids = ["GSM4805563", "GSM4805560",'GSM4805558']

condition_dict = {
    "GSM4805558": "Healthy",
    "GSM4805560": "Healthy",
    'GSM4805563': 'Healthy'
}

sex_dict = {
    "GSM4805563": "Not mentioned",
    "GSM4805560": "Not mentioned",
    'GSM4805558': 'Not mentioned'
}

GSE158691 = {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE158691[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE158691/GSM4805563/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE158691/GSM4805560/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE158691/GSM4805558/pre-processed_anndata.h5ad

# %%
# GSE153596

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE153596"
gsm_ids = ["GSM4647785", "GSM4647786",'GSM4647787','GSM4647788',
           'GSM4647789','GSM4647790']

condition_dict = {
    "GSM4647785": "Healthy",
    "GSM4647786": "Healthy",
    'GSM4647787': 'Healthy',
    'GSM4647788': 'Healthy',
    'GSM4647789': 'Healthy',
    'GSM4647790': 'Healthy'
}

sex_dict = {
    "GSM4647785": "Not mentioned",
    "GSM4647786": "Not mentioned",
    'GSM4647787': 'Not mentioned',
    'GSM4647788': 'Not mentioned',
    'GSM4647789': 'Not mentioned',
    'GSM4647790': 'Not mentioned'
}

GSE153596 = {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE153596[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE153596/GSM4647785/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE153596/GSM4647786/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE153596/GSM4647787/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE153596/GSM4647788/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE153596/GSM4647789/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE153596/GSM4647790/pre-processed_anndata.h5ad

# %%
# GSE146122

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE146122"
gsm_ids = ["GSM4378540", "GSM4378541",'GSM4378542']

condition_dict = {
    "GSM4378540": "Healthy",
    "GSM4378541": "Healthy",
    'GSM4378542': 'Healthy'
}

sex_dict = {
    "GSM4378540": "Not mentioned",
    "GSM4378541": "Not mentioned",
    'GSM4378542': 'Not mentioned'
}

GSE146122 = {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE146122[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE146122/GSM4378540/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE146122/GSM4378541/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE146122/GSM4378542/pre-processed_anndata.h5ad

# %%
# GSE122043

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE122043"
gsm_ids = ["GSM3453536", "GSM3453538"]

condition_dict = {
    "GSM3453536": "Healthy",
    "GSM3453538": "Healthy"
}

sex_dict = {
    "GSM3453536": "Not mentioned",
    "GSM3453538": "Not mentioned"
}

GSE122043 = {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE122043[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE122043/GSM3453536/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE122043/GSM3453538/pre-processed_anndata.h5ad

# %%
# GSE212673

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE212673"
gsm_ids = ["GSM6543169", "GSM6543170","GSM6543171"]

condition_dict = {
    "GSM6543169": "Healthy",
    "GSM6543170": "Healthy",
    "GSM6543171": "Healthy"
}

sex_dict = {
    "GSM6543169": "Not mentioned",
    "GSM6543170": "Not mentioned",
    "GSM6543171": "Not mentioned"
}

GSE212673 = {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE212673[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE212673/GSM6543169/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE212673/GSM6543170/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE212673/GSM6543171/pre-processed_anndata.h5ad

# %%
# GSE165021

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE165021"
gsm_ids = ["GSM5024746","GSM5024747","GSM5024748","GSM5024749","GSM5024750",
           "GSM5024751"]

condition_dict = {
    "GSM5024746": "Healthy",
    "GSM5024747": "Healthy",
    "GSM5024748": "imiquimod (IMQ)-induced",
    "GSM5024749": "imiquimod (IMQ)-induced",
    "GSM5024750": "psoriasis_SHP099",
    "GSM5024751": "psoriasis_SHP099",
}

sex_dict = {
    "GSM5024746": "Not mentioned",
    "GSM5024747": "Not mentioned",
    "GSM5024748": "Not mentioned",
    "GSM5024749": "Not mentioned",
    "GSM5024750": "Not mentioned",
    "GSM5024751": "Not mentioned",
}

GSE165021 = {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE165021[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE165021/GSM5024746/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE165021/GSM5024747/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE165021/GSM5024748/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE165021/GSM5024749/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE165021/GSM5024750/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE165021/GSM5024751/pre-processed_anndata.h5ad

# %%
# GSE236918

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE236918"
gsm_ids = ["GSM7585467","GSM7585468", "GSM7585469","GSM7585470"]

condition_dict = {
    "GSM7585467": "LethalYellow",
    "GSM7585468": "Healthy",
    "GSM7585469": "Recessive yellow",
    "GSM7585470": "Healthy"
}

sex_dict = {
    "GSM7585467": "Not mentioned",
    "GSM7585468": "Not mentioned",
    "GSM7585469": "Not mentioned",
    "GSM7585470": "Not mentioned"
}

GSE236918 = {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE236918[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE236918/GSM7585467/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE236918/GSM7585468/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE236918/GSM7585469/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE236918/GSM7585470/pre-processed_anndata.h5ad

# %%
# GSE272509

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE272509"
gsm_ids = ["GSM8403737","GSM8403738"]

condition_dict = {
    "GSM8403737": "LethalYellow",
    "GSM8403738": "Lesion",
}

sex_dict = {
    "GSM8403737": "Not mentioned",
    "GSM8403738": "Not mentioned",
}

GSE272509 = {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE272509[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE272509/GSM8403737/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE272509/GSM8403738/pre-processed_anndata.h5ad

# %%
# GSE213528

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE213528"
gsm_ids = ["GSM6588784","GSM6588785", "GSM6588786","GSM6588787"]

condition_dict = {
    "GSM6588784": "Healthy",
    "GSM6588785": "Np63 Knockout",
    "GSM6588786": "Healthy",
    "GSM6588787": "Np63 Knockout"
}

sex_dict = {
    "GSM6588784": "Not mentioned",
    "GSM6588785": "Not mentioned",
    "GSM6588786": "Not mentioned",
    "GSM6588787": "Not mentioned"
}

GSE213528= {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE213528[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE213528/GSM6588784/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE213528/GSM6588785/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE213528/GSM6588786/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE213528/GSM6588787/pre-processed_anndata.h5ad

# %%
# GSE261766

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "GSE261766"
gsm_ids = ["GSM8150922", "GSM8150923", "GSM8150924", "GSM8150925", "GSM8150926",
           "GSM8150927", "GSM8150928", "GSM8150929", "GSM8150930", "GSM8150931",
           "GSM8150932", "GSM8150933", "GSM8150934", "GSM8150935", "GSM8150936",
           "GSM8150937", "GSM8150938", "GSM8150940", "GSM8150941", "GSM8150944", 
           "GSM8150946","GSM8150947"]

condition_dict = {
    "GSM8150922": "Squamous cell carcinoma",
    "GSM8150923": "Squamous cell carcinoma",
    "GSM8150924": "Squamous cell carcinoma",
    "GSM8150925": "Papilloma",
    "GSM8150926": "Papilloma",
    "GSM8150927": "Papilloma",
    "GSM8150928": "Healthy",
    "GSM8150929": "Healthy",
    "GSM8150930": "Healthy",
    "GSM8150931": "Healthy",
    "GSM8150932": "Healthy",
    "GSM8150933": "Healthy",
    "GSM8150934": "Squamous cell carcinoma",
    "GSM8150935": "Squamous cell carcinoma",
    "GSM8150936": "Squamous cell carcinoma",
    "GSM8150937": "Squamous cell carcinoma",
    "GSM8150938": "Squamous cell carcinoma",
    "GSM8150940": "Squamous cell carcinoma",
    "GSM8150941": "Squamous cell carcinoma",
    "GSM8150944": "Papilloma",
    "GSM8150946": "Progressing papilloma",
    "GSM8150947": "Progressing papilloma"
}

sex_dict = {
    "GSM8150922": "Not mentioned",
    "GSM8150923": "Not mentioned",
    "GSM8150924": "Not mentioned",
    "GSM8150925": "Not mentioned",
    "GSM8150926": "Not mentioned",
    "GSM8150927": "Not mentioned",
    "GSM8150928": "Not mentioned",
    "GSM8150929": "Not mentioned",
    "GSM8150930": "Not mentioned",
    "GSM8150931": "Not mentioned",
    "GSM8150932": "Not mentioned",
    "GSM8150933": "Not mentioned",
    "GSM8150934": "Not mentioned",
    "GSM8150935": "Not mentioned",
    "GSM8150936": "Not mentioned",
    "GSM8150937": "Not mentioned",
    "GSM8150938": "Not mentioned",
    "GSM8150940": "Not mentioned",
    "GSM8150941": "Not mentioned",
    "GSM8150944": "Not mentioned",
    "GSM8150946": "Not mentioned",
    "GSM8150947": "Not mentioned"
}


GSE261766= {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    GSE261766[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE261766/GSM8150922/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE261766/GSM8150923/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE261766/GSM8150924/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE261766/GSM8150925/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE261766/GSM8150926/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE261766/GSM8150927/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE261766/GSM8150928/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE261766/GSM8150929/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/GSE261766/GSM8150930/pre-processed_anndata.h5ad
# ...

# %%
# CRA004660

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "CRA004660"
gsm_ids = ["SAMC438600","SAMC438601", "SAMC438602","SAMC438603"]

condition_dict = {
    "SAMC438600": "Healthy",
    "SAMC438601": "Healthy",
    "SAMC438602": "Healthy",
    "SAMC438603": "Healthy"
}

sex_dict = {
    "SAMC438600": "male",
    "SAMC438601": "male",
    "SAMC438602": "male",
    "SAMC438603": "male"
}

CRA004660= {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    CRA004660[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/CRA004660/SAMC438600/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/CRA004660/SAMC438601/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/CRA004660/SAMC438602/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/CRA004660/SAMC438603/pre-processed_anndata.h5ad

# %%
#CRA006512

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "CRA006512"
gsm_ids = ["SAMC703634","SAMC703635", "SAMC703636","SAMC703637","SAMC703638","SAMC703639",
           "SAMC703640"
          ]

condition_dict = {
    "SAMC703634": "Healthy",
    "SAMC703635": "Healthy",
    "SAMC703636": "Healthy",
    "SAMC703637": "Healthy",
    "SAMC703638": "Healthy",
    "SAMC703639": "Healthy",
    "SAMC703640": "Healthy"

}

sex_dict = {
    "SAMC703634": "male",
    "SAMC703635": "male",
    "SAMC703636": "male",
    "SAMC703637": "male",
    "SAMC703638": "male",
    "SAMC703639": "male",
    "SAMC703640": "male"
}

CRA006512= {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    CRA006512[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/CRA006512/SAMC703634/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/CRA006512/SAMC703635/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/CRA006512/SAMC703636/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/CRA006512/SAMC703637/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/CRA006512/SAMC703638/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/CRA006512/SAMC703639/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/CRA006512/SAMC703640/pre-processed_anndata.h5ad

# %%
#CRA028265

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "CRA028265"
gsm_ids = ["SAMC5706929","SAMC5706930"]

condition_dict = {
    "SAMC5706929": "imiquimod (IMQ)-induced",
    "SAMC5706930": "imiquimod (IMQ)-induced"
}

sex_dict = {
    "SAMC5706929": "male",
    "SAMC5706930": "male"
}

CRA028265= {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    CRA028265[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/CRA028265/SAMC5706929/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/CRA028265/SAMC5706930/pre-processed_anndata.h5ad

# %%
#CRA028974

# %%
base_dir = "/gpfsdata/home/renyixiang/SkinDB/10X/mouse/"
gse_id = "CRA028974"
gsm_ids = ["SAMC5773650","SAMC5773651", "SAMC5773652","SAMC5773653","SAMC5773654","SAMC5773655",
           "SAMC5773656",
           "SAMC5773657"]

condition_dict = {
    "SAMC5773650": "Card9-knockout",
    "SAMC5773651": "Healthy",
    "SAMC5773652": "Card9-knockout",
    "SAMC5773653": "Healthy",
    "SAMC5773654": "Card9-knockout",
    "SAMC5773655": "Healthy",
    "SAMC5773656": "Card9-knockout",
    "SAMC5773657": "Healthy"

}

sex_dict = {
    "SAMC5773650": "male",
    "SAMC5773651": "male",
    "SAMC5773652": "male",
    "SAMC5773653": "male",
    "SAMC5773654": "male",
    "SAMC5773655": "male",
    "SAMC5773656": "male",
    "SAMC5773657": "male"
}

CRA028974= {}

for gsm_id in gsm_ids:
    file_path = os.path.join(base_dir, gse_id, gsm_id, "pre-processed_anndata.h5ad")
    print(f"Loading: {file_path}")
    
    adata = sc.read_h5ad(file_path)
    adata.obs['species'] = "mouse"
    adata.obs['GSE'] = gse_id
    adata.obs['GSM'] = gsm_id
    adata.obs['batch'] = f"{gse_id}_{gsm_id}"
    adata.obs['original_annotation'] = "unknown"
    adata.obs['condition'] = condition_dict[gsm_id]
    adata.obs['sex'] = sex_dict[gsm_id]
    
    CRA028974[gsm_id] = adata
# Out:
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/CRA028974/SAMC5773650/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/CRA028974/SAMC5773651/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/CRA028974/SAMC5773652/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/CRA028974/SAMC5773653/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/CRA028974/SAMC5773654/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/CRA028974/SAMC5773655/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/CRA028974/SAMC5773656/pre-processed_anndata.h5ad
# Loading: /gpfsdata/home/renyixiang/SkinDB/10X/mouse/CRA028974/SAMC5773657/pre-processed_anndata.h5ad

# %%
def merge_GSE_dicts(*gse_dicts):
    all_adatas = []
    for gse_dict in gse_dicts:
        all_adatas.extend(list(gse_dict.values()))
    
    merged = ad.concat(all_adatas, join="outer", index_unique=None)
    return merged

adata_merged = merge_GSE_dicts(GSE269455, GSE261227, GSE234269, GSE230512, GSE223660,
                               GSE211810, GSE211381, GSE211279, GSE210224, GSE205020,
                               GSE196677, GSE189210, GSE158691, GSE153596, GSE146122,
                               GSE122043, GSE261766, GSE213528, GSE272509, GSE236918,
                               GSE165021, GSE212673, CRA004660, CRA006512, CRA028265,
                               CRA028974)
adata_merged
adata_merged.var_names_make_unique()
# Out:
# /gpfsdata/home/renyixiang/miniconda3/envs/scrna/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
# 统计每个 batch 的细胞数
batch_sizes = adata_merged.obs["batch"].value_counts()
print(batch_sizes.sort_values())
min_cells = 350
keep_batches = batch_sizes.index[batch_sizes >= min_cells]
adata_merged = adata_merged[adata_merged.obs['batch'].isin(keep_batches)].copy()
adata_merged.obs_names_make_unique()
# 按照细胞数升序排序
print("after filter")
batch_sizes = adata_merged.obs["batch"].value_counts()
print(batch_sizes.sort_values())
# Out:
# batch
# GSE196677_GSM5898068       384
# GSE205020_GSM6204200       390
# GSE146122_GSM4378541       917
# GSE230512_GSM7225687       965
# GSE211810_GSM6502674      1070
# GSE211381_GSM6468130      1070
# GSE261766_GSM8150946      1445
# GSE261766_GSM8150944      1474
# GSE236918_GSM7585469      1652
# GSE261766_GSM8150947      1677
# GSE153596_GSM4647790      1939
# GSE153596_GSM4647786      1941
# GSE153596_GSM4647789      1969
# GSE212673_GSM6543169      2036
# GSE212673_GSM6543170      2141
# GSE261766_GSM8150925      2206
# GSE261766_GSM8150922      2240
# GSE153596_GSM4647785      2271
# GSE261766_GSM8150931      2280
# GSE261766_GSM8150941      2304
# GSE261766_GSM8150933      2435
# GSE211810_GSM6502672      2458
# GSE211381_GSM6468128      2458
# GSE211381_GSM6468129      2574
# GSE211810_GSM6502673      2574
# GSE210224_GSM6423817      2672
# GSE153596_GSM4647788      2763
# GSE236918_GSM7585470      2778
# GSE212673_GSM6543171      2853
# GSE261766_GSM8150932      2895
# ...

# %%
adata_merged.write('/gpfsdata/home/renyixiang/SkinDB/10X/mouse/Integration/Mouse_merged_before_int_2.h5ad')

# %%
#change batch key to species
adata_merged.obs['percent.mt']=adata_merged.obs['pct_counts_mt']
adata_merged.raw = adata_merged # freeze the state in `.raw`
sc.pp.highly_variable_genes(
    adata_merged,
    n_top_genes=8000,
    subset=True,
    layer="counts",
    flavor="seurat_v3",
    batch_key="batch",
    span=0.6  
)
# Out:
# /gpfsdata/home/renyixiang/miniconda3/envs/scrna/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /gpfsdata/home/renyixiang/miniconda3/envs/scrna/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
adata_merged.write('/gpfsdata/home/renyixiang/SkinDB/10X/mouse/Integration/Mouse_merged_before_int8000HVG_2.h5ad')
